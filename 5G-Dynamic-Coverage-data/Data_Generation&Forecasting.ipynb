# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt

# %%
time0weekday = pd.DataFrame(np.around(np.random.normal(55, 10, size=(50, 5)).astype("float"), 3))
time0weekend = pd.DataFrame(np.around(np.random.normal(41, 10, size=(50, 2)).astype("float"), 3))
time0 = pd.merge(time0weekday, time0weekend, left_index=True, right_index=True)
time0.insert(0, "Hour", [0]*50)
time1weekday = pd.DataFrame(np.around(np.random.normal(53, 10, size=(50, 5)).astype("float"), 3))
time1weekend = pd.DataFrame(np.around(np.random.normal(38, 10, size=(50, 2)).astype("float"), 3))
time1 = pd.merge(time1weekday, time1weekend, left_index=True, right_index=True)
time1.insert(0, "Hour", [1]*50)
time2weekday = pd.DataFrame(np.around(np.random.normal(41, 10, size=(50, 5)).astype("float"), 3))
time2weekend = pd.DataFrame(np.around(np.random.normal(39, 10, size=(50, 2)).astype("float"), 3))
time2 = pd.merge(time2weekday, time2weekend, left_index=True, right_index=True)
time2.insert(0, "Hour", [2]*50)

time3 = pd.DataFrame(np.around(np.random.normal(40, 10, size=(50, 7)).astype("float"), 3))
time3.insert(0, "Hour", [3]*50)
time4 = pd.DataFrame(np.around(np.random.normal(38, 10, size=(50, 7)).astype("float"), 3))
time4.insert(0, "Hour", [4]*50)
time5 = pd.DataFrame(np.around(np.random.normal(40, 10, size=(50, 7)).astype("float"), 3))
time5.insert(0, "Hour", [5]*50)
time6 = pd.DataFrame(np.around(np.random.normal(39, 10, size=(50, 7)).astype("float"), 3))
time6.insert(0, "Hour", [6]*50)


time7weekday = pd.DataFrame(np.around(np.random.normal(46, 10, size=(50, 5)).astype("float"), 3))
time7weekend = pd.DataFrame(np.around(np.random.normal(38, 10, size=(50, 2)).astype("float"), 3))
time7 = pd.merge(time7weekday, time7weekend, left_index=True, right_index=True)
time7.insert(0, "Hour", [7]*50)

time8weekday = pd.DataFrame(np.around(np.random.normal(48, 10, size=(50, 5)).astype("float"), 3))
time8weekend = pd.DataFrame(np.around(np.random.normal(38, 10, size=(50, 2)).astype("float"), 3))
time8 = pd.merge(time8weekday, time8weekend, left_index=True, right_index=True)
time8.insert(0, "Hour", [8]*50)

time9weekday = pd.DataFrame(np.around(np.random.normal(54, 10, size=(50, 5)).astype("float"), 3))
time9weekend = pd.DataFrame(np.around(np.random.normal(37, 10, size=(50, 2)).astype("float"), 3))
time9 = pd.merge(time9weekday, time9weekend, left_index=True, right_index=True)
time9.insert(0, "Hour", [9]*50)

time10weekday = pd.DataFrame(np.around(np.random.normal(59, 10, size=(50, 5)).astype("float"), 3))
time10weekend = pd.DataFrame(np.around(np.random.normal(40, 10, size=(50, 2)).astype("float"), 3))
time10 = pd.merge(time10weekday, time10weekend, left_index=True, right_index=True)
time10.insert(0, "Hour", [10]*50)

time11weekday = pd.DataFrame(np.around(np.random.normal(61, 10, size=(50, 5)).astype("float"), 3))
time11weekend = pd.DataFrame(np.around(np.random.normal(39, 10, size=(50, 2)).astype("float"), 3))
time11 = pd.merge(time11weekday, time11weekend, left_index=True, right_index=True)
time11.insert(0, "Hour", [11]*50)

time12weekday = pd.DataFrame(np.around(np.random.normal(72, 10, size=(50, 5)).astype("float"), 3))
time12weekend = pd.DataFrame(np.around(np.random.normal(42, 10, size=(50, 2)).astype("float"), 3))
time12 = pd.merge(time12weekday, time12weekend, left_index=True, right_index=True)
time12.insert(0, "Hour", [12]*50)

time13weekday = pd.DataFrame(np.around(np.random.normal(86, 10, size=(50, 5)).astype("float"), 3))
time13weekend = pd.DataFrame(np.around(np.random.normal(54, 10, size=(50, 2)).astype("float"), 3))
time13 = pd.merge(time13weekday, time13weekend, left_index=True, right_index=True)
time13.insert(0, "Hour", [13]*50)

time14weekday = pd.DataFrame(np.around(np.random.normal(80, 10, size=(50, 5)).astype("float"), 3))
time14weekend = pd.DataFrame(np.around(np.random.normal(59, 10, size=(50, 2)).astype("float"), 3))
time14 = pd.merge(time14weekday, time14weekend, left_index=True, right_index=True)
time14.insert(0, "Hour", [14]*50)

time15weekday = pd.DataFrame(np.around(np.random.normal(77, 10, size=(50, 5)).astype("float"), 3))
time15weekend = pd.DataFrame(np.around(np.random.normal(59, 10, size=(50, 2)).astype("float"), 3))
time15 = pd.merge(time15weekday, time15weekend, left_index=True, right_index=True)
time15.insert(0, "Hour", [15]*50)

time16weekday = pd.DataFrame(np.around(np.random.normal(64, 10, size=(50, 5)).astype("float"), 3))
time16weekend = pd.DataFrame(np.around(np.random.normal(61, 10, size=(50, 2)).astype("float"), 3))
time16 = pd.merge(time16weekday, time16weekend, left_index=True, right_index=True)
time16.insert(0, "Hour", [16]*50)

time17weekday = pd.DataFrame(np.around(np.random.normal(63, 10, size=(50, 5)).astype("float"), 3))
time17weekend = pd.DataFrame(np.around(np.random.normal(61, 10, size=(50, 2)).astype("float"), 3))
time17 = pd.merge(time17weekday, time17weekend, left_index=True, right_index=True)
time17.insert(0, "Hour", [17]*50)

time18weekday = pd.DataFrame(np.around(np.random.normal(59, 10, size=(50, 5)).astype("float"), 3))
time18weekend = pd.DataFrame(np.around(np.random.normal(62, 10, size=(50, 2)).astype("float"), 3))
time18 = pd.merge(time18weekday, time18weekend, left_index=True, right_index=True)
time18.insert(0, "Hour", [18]*50)

time19weekday = pd.DataFrame(np.around(np.random.normal(56, 10, size=(50, 5)).astype("float"), 3))
time19weekend = pd.DataFrame(np.around(np.random.normal(50, 10, size=(50, 2)).astype("float"), 3))
time19 = pd.merge(time19weekday, time19weekend, left_index=True, right_index=True)
time19.insert(0, "Hour", [19]*50)

time20weekday = pd.DataFrame(np.around(np.random.normal(55, 10, size=(50, 5)).astype("float"), 3))
time20weekend = pd.DataFrame(np.around(np.random.normal(46, 10, size=(50, 2)).astype("float"), 3))
time20 = pd.merge(time20weekday, time20weekend, left_index=True, right_index=True)
time20.insert(0, "Hour", [20]*50)

time21weekday = pd.DataFrame(np.around(np.random.normal(56, 10, size=(50, 5)).astype("float"), 3))
time21weekend = pd.DataFrame(np.around(np.random.normal(46, 10, size=(50, 2)).astype("float"), 3))
time21 = pd.merge(time21weekday, time21weekend, left_index=True, right_index=True)
time21.insert(0, "Hour", [21]*50)

time22weekday = pd.DataFrame(np.around(np.random.normal(55, 10, size=(50, 5)).astype("float"), 3))
time22weekend = pd.DataFrame(np.around(np.random.normal(40, 10, size=(50, 2)).astype("float"), 3))
time22 = pd.merge(time22weekday, time22weekend, left_index=True, right_index=True)
time22.insert(0, "Hour", [22]*50)

time23weekday = pd.DataFrame(np.around(np.random.normal(53, 10, size=(50, 5)).astype("float"), 3))
time23weekend = pd.DataFrame(np.around(np.random.normal(39, 10, size=(50, 2)).astype("float"), 3))
time23 = pd.merge(time23weekday, time23weekend, left_index=True, right_index=True)
time23.insert(0, "Hour", [23]*50)

# %%
frames1 = [time3, time4, time5, time6]
frames2 = [time0, time1, time2, time7, time8, time9, time10, time11, time12, time13, time14, time15, time16, time17, time18, time19, time20, time21, time22, time23]
latency1 = pd.concat(frames1)
latency2 = pd.concat(frames2)
latency1 = latency1.rename(columns={ 0:"Monday", 1:"Tuesday", 2: "Wednesday", 3:"Thursday", 4:"Friday", 5:"Saturday", 6:"Sunday"})
latency2 = latency2.rename(columns={'0_x':"Monday", '1_x':"Tuesday", 2: "Wednesday", 3:"Thursday", 4:"Friday", '0_y':"Saturday", '1_y':"Sunday"})
latency = pd.concat([latency1, latency2]).sort_values(by=['Hour'])

# %%
# to excel command
#latency.to_excel("latency.xlsx")

# %%
lat1 = latency.groupby(['Hour']).mean()
#lat1.to_excel("latency_agg.xlsx")

# %%
Mon = lat1[['Monday']].rename(columns = {"Monday":"Latency"})
Mon.insert(0, "Weekday", ['Monday']*24)
Tue = lat1[['Tuesday']].rename(columns = {"Tuesday":"Latency"})
Tue.insert(0, "Weekday", ['Tuesday']*24)
Wed = lat1[['Wednesday']].rename(columns = {"Wednesday":"Latency"})
Wed.insert(0, "Weekday", ['Wednesday']*24)
Thu = lat1[['Thursday']].rename(columns = {"Thursday":"Latency"})
Thu.insert(0, "Weekday", ['Thursday']*24)
Fri = lat1[['Friday']].rename(columns = {"Friday":"Latency"})
Fri.insert(0, "Weekday", ['Friday']*24)
Sat = lat1[['Saturday']].rename(columns = {"Saturday":"Latency"})
Sat.insert(0, "Weekday", ['Saturday']*24)
Sun = lat1[['Sunday']].rename(columns = {"Sunday":"Latency"})
Sun.insert(0, "Weekday", ['Sunday']*24)
time = pd.concat([Mon, Tue, Wed, Thu, Fri, Sat, Sun]).reset_index()
time.set_index(['Weekday', 'Hour'], inplace=True)

# %%
time['Wifi'] = time['Latency']/1.827 + 2.1
time
#time.to_excel("multi.xlsx")
# Out:
#                 Latency       Wifi
# Weekday  Hour
# Monday   0     56.21352  32.868210
#          1     50.91944  29.970520
#          2     40.62008  24.333213
#          3     39.80270  23.885824
#          4     35.67130  21.624521
#          5     38.98672  23.439201
#          6     39.31470  23.618719
#          7     43.84230  26.096880
#          8     47.35260  28.018227
#          9     54.26124  31.799639
#          10    57.89012  33.785889
#          11    63.11922  36.648013
#          12    74.46494  42.858041
#          13    86.00518  49.174537
#          14    81.09580  46.487411
#          15    75.85500  43.618883
#          16    62.98280  36.573344
#          17    63.53252  36.874231
#          18    57.59648  33.625167
#          19    56.03492  32.770454
#          20    52.62774  30.905550
#          21    57.91452  33.799245
#          22    57.29064  33.457767
#          23    52.49030  30.830323
# Tuesday  0     55.27180  32.352764
# ...

# %%
plt.figure(figsize=(20, 10))

# set xtick sizes
ax = plt.axes()
xticks = np.arange(0, 400, 20)
ax.set_xticks(xticks)
plt.xticks(fontsize=15, rotation=90)
plt.yticks(fontsize=20, rotation=90)

plt.xlabel('(Weekday, Hour)', fontsize=20)
plt.ylabel('Latency', fontsize=20)

ax = time['Latency'].plot(kind='line')
ax = time['Wifi'].plot(kind='line')
ax.legend(fontsize='x-large');

# %%
# ARIMA model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf

# %%
time = time.reset_index()

# %%
# Differentiate the time series and visualize the autocorrelation plot
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(time.Latency)
axes[0, 0].set_title('Original Series')
plot_acf(time.Latency, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(time.Latency.diff())
axes[1, 0].set_title('1st Order Differencing')
plot_acf(time.Latency.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(time.Latency.diff().diff())
axes[2, 0].set_title('2nd Order Differencing')
plot_acf(time.Latency.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(time.Latency.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(time.Latency.diff().dropna(), ax=axes[1])
plt.show()
warnings.filterwarnings('ignore')
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(time.Latency.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(time.Latency.diff().dropna(), ax=axes[1])

plt.show()

# %%
# build the ARIMA model, p=1, d=0, q=1
model = ARIMA(time.Latency, order=(1, 1, 1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:              D.Latency   No. Observations:                  167
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -517.928
# Method:                       css-mle   S.D. of innovations              5.377
# Date:                Wed, 22 Apr 2020   AIC                           1043.856
# Time:                        22:01:29   BIC                           1056.328
# Sample:                             1   HQIC                          1048.918
#
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.1421      0.665     -0.214      0.831      -1.446       1.161
# ar.L1.D.Latency     0.5605      0.144      3.883      0.000       0.278       0.843
# ma.L1.D.Latency    -0.2943      0.157     -1.877      0.062      -0.602       0.013
# ...

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# The residual errors seem fine with near zero mean and uniform variance. 
# Actual vs Fitted
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
# Forecast
fitted = model.fit(disp=-1)
fc, se, conf = fitted.forecast(42, alpha=0.05) #95%conf
train  = time.Latency[:126]
test = time.Latency[126:]

# Accuracy metrics
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # Mean Absolute Percentage Error
    mae = np.mean(np.abs(forecast - actual))    # Mean Absolute Error
    mpe = np.mean((forecast - actual)/actual)   # Mean Percentage Error
    rmse = np.mean((forecast - actual)**2)**.5  # Root Mean Square Error
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-test)[1]                      # Lag1 Autocorrelation Error
    return({'Mean Absolute Percentage Error':round(mape, 3)})

forecast_accuracy(fc, test)
# Out:
# {'Mean Absolute Percentage Error': 0.221}
