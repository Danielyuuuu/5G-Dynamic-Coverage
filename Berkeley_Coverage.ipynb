# %%
import pandas as pd
import numpy as np
import gmaps
import gmaps.datasets

# %%
gmaps.configure(api_key='AIzaSyAsaMbdSGc5v_vcnBkxhFKMK7fW8vlX_iw')
berkeley_coordinates = (37.871853, -122.258423)
gmaps.figure(center = berkeley_coordinates, zoom_level=15)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
Hotspot = pd.DataFrame(np.array([['moffit', (37.8726, -122.2607), 74.300], ['mlk', (37.8692, -122.2597), 66.484], \
                        ['barrow', (37.8703, -122.2581), 69.615], ['lower_hearst', (37.8752, -122.2615), 66.132], \
                       ['soda', (37.8756, -122.2588), 289.824], ['foothill', (37.8753, -122.2560), 55.795], \
                       ['Crescent', (37.871716, -122.264999), 62.023]]), columns=['building', 'location', 'latency'])

# %%
Hotspot
# Out:
#        building                  location  latency
# 0        moffit      (37.8726, -122.2607)     74.3
# 1           mlk      (37.8692, -122.2597)   66.484
# 2        barrow      (37.8703, -122.2581)   69.615
# 3  lower_hearst      (37.8752, -122.2615)   66.132
# 4          soda      (37.8756, -122.2588)  289.824
# 5      foothill       (37.8753, -122.256)   55.795
# 6      Crescent  (37.871716, -122.264999)   62.023

# %%
# Get the locations form the df
locations = Hotspot['location']

# Get the magnitude from the data
weights = Hotspot['latency']

#Set up the map
fig = gmaps.figure()
heatmap = gmaps.heatmap_layer(locations, weights=weights)
# Any density of points greater than that walue will get mapped to the hottest color
heatmap.max_intensity = 80
# radius of influence
heatmap.point_radius = 25
fig.add_layer(heatmap)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
ping_mlk = pd.read_csv('moffit446.txt', sep=" ", engine='python', skiprows=[0], skipfooter=3, header=None)

# %%
ping_mlk = ping_mlk[[3, 4, 6]].rename(columns={3: 'Location', 4:'icmp_seq', 6:'Time(ms)'})
ping_mlk['icmp_seq'] = ping_mlk['icmp_seq'].str[9:]
ping_mlk['Longitude'] = ping_mlk['Location'].str[:6]
ping_mlk['Latitude'] = ping_mlk['Location'].str[7:-1]
ping_mlk['Time(ms)'] = ping_mlk['Time(ms)'].str[6:]
ping_mlk = ping_mlk.drop(['Location'], axis=1)
ping_mlk = ping_mlk.set_index('icmp_seq')

# %%
ping_mlk
# Out:
#       0      1     2              3             4       5             6   7
# 0    64  bytes  from  172.217.6.78:    icmp_seq=0  ttl=52   time=50.295  ms
# 1    64  bytes  from  172.217.6.78:    icmp_seq=1  ttl=52   time=64.746  ms
# 2    64  bytes  from  172.217.6.78:    icmp_seq=2  ttl=52   time=55.652  ms
# 3    64  bytes  from  172.217.6.78:    icmp_seq=3  ttl=52   time=61.969  ms
# 4    64  bytes  from  172.217.6.78:    icmp_seq=4  ttl=52   time=53.792  ms
# 5    64  bytes  from  172.217.6.78:    icmp_seq=5  ttl=52   time=66.487  ms
# 6    64  bytes  from  172.217.6.78:    icmp_seq=6  ttl=52   time=86.142  ms
# 7    64  bytes  from  172.217.6.78:    icmp_seq=7  ttl=52   time=51.055  ms
# 8    64  bytes  from  172.217.6.78:    icmp_seq=8  ttl=52   time=48.802  ms
# 9    64  bytes  from  172.217.6.78:    icmp_seq=9  ttl=52   time=78.467  ms
# 10   64  bytes  from  172.217.6.78:   icmp_seq=10  ttl=52   time=76.435  ms
# ...

# %%
ping_mlk.to_excel('mlk330LTE.xlsx')

# %%
# Out:
#        building              location latency
# 0        moffit  (37.8726, -122.2607)    74.3
# 1           mlk  (37.8692, -122.2597)  66.484
# 2        barrow  (37.8703, -122.2581)  69.615
# 3  lower_hearst  (37.8752, -122.2615)  66.132
